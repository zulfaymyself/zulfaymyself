# %% [markdown]
# <a href="https://colab.research.google.com/github/zulfaymyself/zulfaymyself/blob/main/zulfay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

np.average([10,20,30,40,50])
# Out:
# np.float64(30.0)
